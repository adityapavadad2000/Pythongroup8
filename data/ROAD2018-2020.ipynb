# %%
import matplotlib.pyplot as plt

goods = [
    "Total",
    "Agriculture, Hunting, Forestry, and Fishing",
    "Coal and Natural Gas",
    "Mining and Quarrying",
    "Food and Beverages",
    "Textiles and Leather",
    "Wood Products",
    "Petroleum Products",
    "Chemicals and Rubber",
    "Non-Metallic Minerals",
    "Basic Metals",
    "Machinery and Equipment",
    "Transport Equipment",
    "Furniture",
    "Secondary Raw Materials",
    "Mail and Parcels",
    "Transport of Goods",
    "Non-Market Goods",
    "Grouped Goods",
    "Unidentifiable Goods",
]

percentages = [
    -0.629079668,
    -8.580947236,
    -40.54054054,
    -2.761189558,
    -3.838419637,
    -7.588279489,
    -3.281533804,
    5.839804276,
    1.333271679,
    2.449315781,
    20.55765161,
    -3.057329655,
    19.95599845,
    10.51724138,
    15.02282712,
    -15.95950894,
    -9.357700766,
    7.532956685,
    2.889692864,
    -7.075152336,
]

positive_percentages = [x if x > 0 else 0 for x in percentages]
negative_percentages = [x if x < 0 else 0 for x in percentages]

fig, ax = plt.subplots(figsize=(12, 8))

ax.barh(goods, positive_percentages, color='lightgreen', label='Positive', edgecolor='black')

ax.barh(goods, negative_percentages, color='lightcoral', label='Negative', edgecolor='black')

for i in range(len(goods)):
    if positive_percentages[i] != 0:
        ax.text(positive_percentages[i] + 1, i, f'{positive_percentages[i]:.2f}%', va='center', fontsize=10, color='green')
    if negative_percentages[i] != 0:
        ax.text(negative_percentages[i] - 5, i, f'{negative_percentages[i]:.2f}%', va='center', fontsize=10, color='red')

ax.set_xlim(-45, max(positive_percentages) + 2)  


plt.xlabel('Percentage Change')
plt.title('Percentage Change of Goods (2018-2020)')
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

goods = [
    "Total",
    "Agriculture, Hunting, Forestry, and Fishing",
    "Coal and Natural Gas",
    "Mining and Quarrying",
    "Food and Beverages",
    "Textiles and Leather",
    "Wood Products",
    "Petroleum Products",
    "Chemicals and Rubber",
    "Non-Metallic Minerals",
    "Basic Metals",
    "Machinery and Equipment",
    "Transport Equipment",
    "Furniture",
    "Secondary Raw Materials",
    "Mail and Parcels",
    "Transport of Goods",
    "Non-Market Goods",
    "Grouped Goods",
    "Unidentifiable Goods",
]

percentages = [
    -0.629079668,
    -8.580947236,
    -40.54054054,
    -2.761189558,
    -3.838419637,
    -7.588279489,
    -3.281533804,
    5.839804276,
    1.333271679,
    2.449315781,
    20.55765161,
    -3.057329655,
    19.95599845,
    10.51724138,
    15.02282712,
    -15.95950894,
    -9.357700766,
    7.532956685,
    2.889692864,
    -7.075152336,
]

positive_percentages = [x if x > 0 else 0 for x in percentages]
negative_percentages = [x if x < 0 else 0 for x in percentages]

fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.4
index = np.arange(len(goods))

ax.bar(index, positive_percentages, bar_width, color='lightgreen', label='Positive',edgecolor='black')
ax.bar(index, negative_percentages, bar_width, color='lightcoral', label='Negative',edgecolor='black')

for i, (pos, neg) in enumerate(zip(positive_percentages, negative_percentages)):
    if pos > 0:
        ax.text(i, pos + 2, f'{pos:.2f}%', ha='center', va='bottom', fontsize=10, color='green')
    if neg < 0:
        ax.text(i, neg - 2, f'{neg:.2f}%', ha='center', va='top', fontsize=10, color='red')

ax.set_xticks(index)
ax.set_xticklabels(goods, rotation=90, fontsize=10)

ax.set_ylim(top=30, bottom=-45)  

plt.ylabel('Percentage Change')
plt.title('Percentage Change of Goods (2018-2020)')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

plt.show()
