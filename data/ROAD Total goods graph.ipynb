# %% [markdown]
# **The following program below is function which takes the "Year" as an input and gives the pie chart distribution for all the various types of goods transfered (in % to the total goods transfered) in that respective year. The type of good legend has been kept constant for all the years from 2008 to 2021, this will give us a clear picture of the change in the % of type of good over the years**

# %%
import pandas as pd
import plotly.io as pio
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data_(Road)_1.csv")
df
# Out:
#        Year    Amount             Type of good
# 0    2008.0  6,21,287  Total transported goods
# 1       NaN       NaN  Total transported goods
# 2    2009.0  6,16,903  Total transported goods
# 3       NaN       NaN  Total transported goods
# 4    2010.0  6,57,874  Total transported goods
# ..      ...       ...                      ...
# 655     NaN       NaN  Total transported goods
# 656     NaN       NaN                      NaN
# 657     NaN       NaN  Total transported goods
# 658     NaN       NaN                      NaN
# 659     NaN       NaN  Total transported goods
#
# [660 rows x 3 columns]

# %%
df['Year'] = df['Year'].astype(str).str.replace('.0', '', regex=False)

df = df.dropna()

df['Amount'] = df['Amount'].map(lambda x: x.replace(',', ''))
df['Year'] = pd.Series(df['Year'], dtype='int')
df['Amount'] = pd.Series(df['Amount'], dtype='float')

dp
# Out:
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\2813930454.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount'] = df['Amount'].map(lambda x: x.replace(',', ''))
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\2813930454.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = pd.Series(df['Year'], dtype='int')
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\2813930454.py:7: SettingWithCopyWarning:
# ...

# %%
dp =  df.groupby("Type of good").get_group("Total transported goods")
dp
# Out:
#     Year    Amount             Type of good
# 0   2008  621287.0  Total transported goods
# 2   2009  616903.0  Total transported goods
# 4   2010  657874.0  Total transported goods
# 6   2011  658032.0  Total transported goods
# 8   2012  631898.0  Total transported goods
# 10  2013  642236.0  Total transported goods
# 12  2014  640018.0  Total transported goods
# 14  2015  641875.0  Total transported goods
# 16  2016  656562.0  Total transported goods
# 18  2017  666166.0  Total transported goods
# 20  2018  680186.0  Total transported goods
# 22  2019  688995.0  Total transported goods
# 24  2020  684492.0  Total transported goods
# 26  2021  702161.0  Total transported goods
# 28  2022  695112.0  Total transported goods

# %%
dg = dp.loc[14:28]
dg
# Out:
#     Year    Amount             Type of good
# 14  2015  641875.0  Total transported goods
# 16  2016  656562.0  Total transported goods
# 18  2017  666166.0  Total transported goods
# 20  2018  680186.0  Total transported goods
# 22  2019  688995.0  Total transported goods
# 24  2020  684492.0  Total transported goods
# 26  2021  702161.0  Total transported goods
# 28  2022  695112.0  Total transported goods

# %%
import plotly.express as px

# Assuming you have a DataFrame named dg with columns "Year" and "Amount"
fig = px.line(
    dg,
    x="Year",
    y="Amount",
    title="Total amount of freight transported",
    line_shape='linear',  
    hover_data=["Amount"],  
    
    template='plotly_white',  # Use 'plotly_white' template for a light background with grid
    color_discrete_sequence=px.colors.qualitative.Plotly,
    markers=True, 


fig.update_layout(
    xaxis_title="Years",
    yaxis_title="Amount (Thousand tonnes)",
    title_x=0.5,  
    font=dict(family="Arial", size=14, color="black"),  
    legend=dict(title="Legend Title"),
    margin=dict(l=20, r=20, t=40, b=20),  
)

# Customize line style using 'line_dash'
fig.update_traces(line=dict(dash='solid'))

# Show the plot
fig.show()
# Out:
# <div>                            <div id="aa159f66-dcff-4a2a-a44f-527f99aedcf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa159f66-dcff-4a2a-a44f-527f99aedcf7")) {                    Plotly.newPlot(                        "aa159f66-dcff-4a2a-a44f-527f99aedcf7",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636EFA","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[641875.0,656562.0,666166.0,680186.0,688995.0,684492.0,702161.0,695112.0],"yaxis":"y","type":"scatter"}],                        {"templ
# ...

# %%
# fig, ax = plt.subplots()
# # Plot the data on the axis
# ax.plot(dp["Year"], dp["Amount"], color="red", label="Your Label")

# # Customize the plot if needed
# ax.set_xlabel("Year")
# ax.set_ylabel("Amount")
# ax.set_title("Your Plot Title")
# ax.grid()
# ax.legend()
# #
# # Show the plot
# plt.show()

# %%
dp['Year'] = dp['Year'].astype(str).str.replace('.0', '', regex=False)

dp = dp.dropna()

dp['Amount'] = dp['Amount'].map(lambda x: x.replace(',', ''))
dp['Year'] = pd.Series(df['Year'], dtype='int')
dp['Amount'] = pd.Series(df['Amount'], dtype='float')

dp
# Out:
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\753866635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['Year'] = dp['Year'].astype(str).str.replace('.0', '', regex=False)
#       Year    Amount             Type of good
# 0   2008.0  6,21,287  Total transported goods
# 2   2009.0  6,16,903  Total transported goods
# 4   2010.0  6,57,874  Total transported goods
# 6   2011.0  6,58,032  Total transported goods
# 8   2012.0  6,31,898  Total transported goods
# 10  2013.0  6,42,236  Total transported goods
# 12  2014.0  6,40,018  Total transported goods
# 14  2015.0  6,41,875  Total transported goods
# 16  2016.0  6,56,562  Total transported goods
# 18  2017.0  6,66,166  Total transported goods
# ...

# %%
df['Year'] = df['Year'].astype(str).str.replace('.0', '', regex=False)

df = df.dropna()

df['Amount'] = df['Amount'].map(lambda x: x.replace(',', ''))
df['Year'] = pd.Series(df['Year'], dtype='int')
df['Amount'] = pd.Series(df['Amount'], dtype='float')
# Out:
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\983435893.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount'] = df['Amount'].map(lambda x: x.replace(',', ''))
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\983435893.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = pd.Series(df['Year'], dtype='int')
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\983435893.py:7: SettingWithCopyWarning:
# ...

# %%
types = df['Type of good'].unique()
dq = pd.DataFrame(types)
dq
# Out:
#                                                     0
# 0                             Total transported goods
# 1   Products of agriculture, hunting, and forestry...
# 2   Coal and lignite; crude petroleum and natural gas
# 3   Metal ores and other mining and quarrying prod...
# 4                Food products, beverages and tobacco
# 5   Textiles and textile products; leather and lea...
# 6                                   Wood and products
# 7                 Coke and refined petroleum products
# 8   Chemicals, chemical products, and man-made fib...
# 9                 Other non metallic mineral products
# 10  Basic metals; fabricated metal products, excep...
# 11                            Machinery and equipment
# 12                                Transport equipment
# 13                                          Furniture
# 14                            Secondary raw materials
# 15                                      Mail, parcels
# ...

# %%
df.groupby('Type of good').describe()
# Out:
#                                                     Year                    \
#                                                    count    mean       std
# Type of good
# Basic metals; fabricated metal products, except...  15.0  2015.0  4.472136
# Chemicals, chemical products, and man-made fibe...  15.0  2015.0  4.472136
# Coal and lignite; crude petroleum and natural gas   15.0  2015.0  4.472136
# Coke and refined petroleum products                 15.0  2015.0  4.472136
# Equipment and material utilized in the transpor...  15.0  2015.0  4.472136
# Food products, beverages and tobacco                15.0  2015.0  4.472136
# Furniture                                           15.0  2015.0  4.472136
# Goods moved in the course of household and offi...  15.0  2015.0  4.472136
# Grouped goods0 a mixture of types of goods whic...  15.0  2015.0  4.472136
# Machinery and equipment                             15.0  2015.0  4.472136
# ...

# %%
df1 = df[15:].reset_index(drop = True)

# %%
df1.dtypes
# Out:
# Year              int32
# Amount          float64
# Type of good     object
# dtype: object

# %%
import matplotlib.cm as cm

# %%
sm = get_data(2018)

# %%
sm[0]
# Out:
#          Year    Amount                                       Type of good
# Amount
# 8.96 %   2018   60918.0  Products of agriculture, hunting, and forestry...
# 0.05 %   2018     308.0  Coal and lignite; crude petroleum and natural gas
# 14.32 %  2018   97373.0  Metal ores and other mining and quarrying prod...
# 18.35 %  2018  124811.0               Food products, beverages and tobacco
# 0.54 %   2018    3690.0  Textiles and textile products; leather and lea...
# 3.52 %   2018   23962.0                                  Wood and products
# 1.46 %   2018    9950.0                Coke and refined petroleum products
# 9.67 %   2018   65743.0  Chemicals, chemical products, and man-made fib...
# 10.42 %  2018   70898.0                Other non metallic mineral products
# 3.85 %   2018   26202.0  Basic metals; fabricated metal products, excep...
# 3.77 %   2018   25652.0                            Machinery and equipment
# ...

# %%
    def get_data(y):
        df2 = df1[df1['Year'] == y]
        df4 = df[df['Type of good'] == 'Total transported goods']
        tot = df4[df4['Year'] == y]['Amount'].values

        df2.index = (df2['Amount']/tot*100).round(2).map(lambda x: str(x) + ' %')

        return df2, tot

    def plot_pie(y):
        df, tot = get_data(y)
        df.plot.pie(y='Amount', figsize = (6, 6), legend = None, colormap = cmp, ylabel = '', title = f'{y} (Total = {tot[0]})', explode = [0.1]*len(df));        
        labels = df["Type of good"]

# %%
# import matplotlib.pyplot as plt

# # Define a custom colormap (cmp) if needed

# def get_data(y):
#         df2 = df1[df1['Year'] == y]
#         df4 = df[df['Type of good'] == 'Total transported goods']
#         tot = df4[df4['Year'] == y]['Amount'].values

#         df2.index = (df2['Amount']/tot*100).round(2).map(lambda x: str(x) + ' %')

#         return df2, tot


# def plot_pie(y):
#     df, tot = get_data(y)
    
#     # Increase the figure size
#     plt.figure(figsize=(10, 10))
    
#     # Create an explode list with the same length as the data
#     explode = [21] * len(df1)  # Adjust the explosion for each slice
    
#     # Show labels outside the pie chart
#     plt.pie(df['Amount'], labels=df['Type of good'], explode=explode, autopct='%1.1f%%', startangle=140)
#     plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.

#     # Set the title and total
#     plt.title(f'{y} (Total = {tot[0]})')

#     # Show the plot
#     plt.show()

# # Call plot_pie function with the year you want to plot
plot_pie(2018)

# %%
# def plot_pie(y):
#     df, tot = get_data(y)
#     plot = df.plot.pie(y='Amount', figsize=(6, 6), legend=None, colormap=cmp, ylabel='', title=f'{y} (Total = {tot[0]})')
#     return plot

# # Call the plot_pie function to get the plot object and add the legend outside the function
#     plot = plot_pie(2018)
#     labels = dq[0]  # Assuming df is defined outside the function
#     plot.legend(labels=labels)

# %%
cmp = cm.get_cmap('Spectral')
# Out:
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_8204\1785750545.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmp = cm.get_cmap('Spectral')

# %%
import numpy as np

# %%
from IPython.display import Image

image_path = 'road_data_legend.png'  # Replace with the actual file path

Image(filename=image_path)

# %%
sm[0]
# Out:
#          Year    Amount                                       Type of good
# Amount
# 8.96 %   2018   60918.0  Products of agriculture, hunting, and forestry...
# 0.05 %   2018     308.0  Coal and lignite; crude petroleum and natural gas
# 14.32 %  2018   97373.0  Metal ores and other mining and quarrying prod...
# 18.35 %  2018  124811.0               Food products, beverages and tobacco
# 0.54 %   2018    3690.0  Textiles and textile products; leather and lea...
# 3.52 %   2018   23962.0                                  Wood and products
# 1.46 %   2018    9950.0                Coke and refined petroleum products
# 9.67 %   2018   65743.0  Chemicals, chemical products, and man-made fib...
# 10.42 %  2018   70898.0                Other non metallic mineral products
# 3.85 %   2018   26202.0  Basic metals; fabricated metal products, excep...
# 3.77 %   2018   25652.0                            Machinery and equipment
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(aspect="equal"))

recipe = list(sm[0].index)

data = sm[0].Amount.values
outer_colors = cmp(np.arange(20)*20)
wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40, colors = outer_colors)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = f"angle,angleA=0,angleB={ang}"
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

# ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
plot_pie(2018)

# %%
plot_pie(2019)

# %%
plot_pie(2020)

# %%
plot_pie(2021)

# %%
# def get_data(y):
#     df2 = df1[df1['Year'] == y]
#     df4 = df[df['Type of good'] == 'Total transported goods']
#     tot = df4[df4['Year'] == y]['Amount'].values
    
#     df2.index = (df2['Amount']/tot*100).round(2).map(lambda x: str(x) + ' %')
#     print(df2.index)
    
#     return df2, tot

# %%
# get_data(2018)

# %%
import pandas as pd

def get_data(y):
    df2 = df1[df1['Year'] == y]
    df4 = df[df['Type of good'] == 'Total transported goods']
    tot = df4[df4['Year'] == y]['Amount'].values
    
    df2['Percentage'] = (df2['Amount'] / tot * 100).round(2)
    df2['Percentage'] = df2['Percentage'].astype(str) + ' %'
    
    # Reset the index for the DataFrame
    df2 = df2.reset_index(drop=True)
    
    return df2, tot

data, _ = get_data(2018)

# Print the data in tabular form
# print(data)
d_ki = pd.DataFrame(data)
d_ki
# ds = d_ki.set_index("Type of good")
# ds
# Out:
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_5448\1531231270.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Percentage'] = (df2['Amount'] / tot * 100).round(2)
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_5448\1531231270.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Percentage'] = df2['Percentage'].astype(str) + ' %'
#     Year    Amount                                       Type of good  \
# ...

# %%
import pandas as pd

def get_data(y):
    df2 = df1[df1['Year'] == y]
    df4 = df[df['Type of good'] == 'Total transported goods']
    tot = df4[df4['Year'] == y]['Amount'].values
    
    df2['Percentage'] = (df2['Amount'] / tot * 100).round(2)
    df2['Percentage'] = df2['Percentage'].astype(str) + ' %'
    
    # Reset the index for the DataFrame
    df2 = df2.reset_index(drop=True)
    
    return df2, tot

# Create an empty DataFrame to store the data for multiple years
combined_data = pd.DataFrame()

# Iterate over the desired years and concatenate the data
for year in [2018, 2019, 2020, 2021, 2022]:
    data, _ = get_data(year)
    data['Year'] = year
    combined_data = pd.concat([combined_data, data])

# Reorder the columns
combined_data = combined_data[['Type of good', 'Year', 'Percentage' , 'Amount']]
d_new = combined_data
d_new
# d_new.to_csv("road_five_year_data.csv" , index = False)
# d_new = pd.dataframe(combined_data)
# d_new
# Out:
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_5448\2393352483.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Percentage'] = (df2['Amount'] / tot * 100).round(2)
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_5448\2393352483.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Percentage'] = df2['Percentage'].astype(str) + ' %'
# C:\Users\Aditya Pavadad\AppData\Local\Temp\ipykernel_5448\2393352483.py:8: SettingWithCopyWarning:
# ...

# %%
def get_data(y):
    df4 = df[df['Type of good'] == 'Total transported goods']
    print(df4)
    
    return

# %%
get_data(2018)
# Out:
#     Year    Amount             Type of good
# 0   2008  621287.0  Total transported goods
# 2   2009  616903.0  Total transported goods
# 4   2010  657874.0  Total transported goods
# 6   2011  658032.0  Total transported goods
# 8   2012  631898.0  Total transported goods
# 10  2013  642236.0  Total transported goods
# 12  2014  640018.0  Total transported goods
# 14  2015  641875.0  Total transported goods
# 16  2016  656562.0  Total transported goods
# 18  2017  666166.0  Total transported goods
# 20  2018  680186.0  Total transported goods
# 22  2019  688995.0  Total transported goods
# 24  2020  684492.0  Total transported goods
# 26  2021  702161.0  Total transported goods
# 28  2022  695112.0  Total transported goods
