# %%
import matplotlib.pyplot as plt

goods_2020_2022 = [
    "Total",
    "Agriculture, Hunting, Forestry, and Fishing",
    "Coal and Natural Gas",
    "Mining and Quarrying",
    "Food and Beverages",
    "Textiles and Leather",
    "Wood and Products",
    "Coke and Refined Petroleum Products",
    "Chemicals and Rubber",
    "Non-Metallic Mineral Products",
    "Basic Metals",
    "Machinery and Equipment",
    "Transport Equipment",
    "Furniture",
    "Secondary Raw Materials",
    "Mail and Parcels",
    "Equipment and Material for Transport of Goods",
    "Goods Moved in the Course of Household and Office Removals",
    "Grouped Goods",
    "Unidentifiable Goods",
]

percentages_2020_2022 = [
    -2.51637445,
    11.45193932,
    2.371541502,
    8.166086975,
    -9.084350177,
    3.660436137,
    7.010193504,
    7.809633028,
    4.129684616,
    -8.919452487,
    -1.186633326,
    -8.66383625,
    16.14309334,
    0.519930676,
    8.037597717,
    -28.71180715,
    -9.630627955,
    19.86455982,
    -8.051753181,
    4.105726872,
]

positive_percentages_2020_2022 = [x if x > 0 else 0 for x in percentages_2020_2022]
negative_percentages_2020_2022 = [x if x < 0 else 0 for x in percentages_2020_2022]

fig, ax = plt.subplots(figsize=(12, 8))

ax.barh(goods_2020_2022, positive_percentages_2020_2022, color='lightgreen', label='Positive', edgecolor='black')

ax.barh(goods_2020_2022, negative_percentages_2020_2022, color='lightcoral', label='Negative', edgecolor='black')

for i in range(len(goods_2020_2022)):
    if positive_percentages_2020_2022[i] != 0:
        ax.text(positive_percentages_2020_2022[i] + 1, i, f'{positive_percentages_2020_2022[i]:.2f}%', va='center', fontsize=10, color='green')
    if negative_percentages_2020_2022[i] != 0:
        ax.text(negative_percentages_2020_2022[i] - 5, i, f'{negative_percentages_2020_2022[i]:.2f}%', va='center', fontsize=10, color='red')

ax.set_xlim(-35, max(positive_percentages_2020_2022) + 2)  # Adjust the maximum value as needed

plt.xlabel('Percentage Change')
plt.title('Percentage Change of Goods (2020-2022)')
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

goods = [
    "Total",
    "Agriculture, Hunting, Forestry, and Fishing",
    "Coal and Natural Gas",
    "Mining and Quarrying",
    "Food and Beverages",
    "Textiles and Leather",
    "Wood and Products",
    "Coke and Refined Petroleum Products",
    "Chemicals and Rubber",
    "Non-Metallic Mineral Products",
    "Basic Metals",
    "Machinery and Equipment",
    "Transport Equipment",
    "Furniture",
    "Secondary Raw Materials",
    "Mail and Parcels",
    "Equipment and Material for Transport of Goods",
    "Goods Moved in the Course of Household and Office Removals",
    "Grouped Goods",
    "Unidentifiable Goods",
]

percentages_2020_2022 = [
    -2.51637445,
    11.45193932,
    2.371541502,
    8.166086975,
    -9.084350177,
    3.660436137,
    7.010193504,
    7.809633028,
    4.129684616,
    -8.919452487,
    -1.186633326,
    -8.66383625,
    16.14309334,
    0.519930676,
    8.037597717,
    -28.71180715,
    -9.630627955,
    19.86455982,
    -8.051753181,
    4.105726872,
]

positive_percentages_2020_2022 = [x if x > 0 else 0 for x in percentages_2020_2022]
negative_percentages_2020_2022 = [x if x < 0 else 0 for x in percentages_2020_2022]

fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.4
index = np.arange(len(goods))

ax.bar(index, positive_percentages_2020_2022, bar_width, color='lightgreen', label='Positive', edgecolor='black')
ax.bar(index, negative_percentages_2020_2022, bar_width, color='lightcoral', label='Negative', edgecolor='black')

for i, (pos, neg) in enumerate(zip(positive_percentages_2020_2022, negative_percentages_2020_2022)):
    if pos > 0:
        ax.text(i, pos + 2, f'{pos:.2f}%', ha='center', va='bottom', fontsize=10, color='green')
    if neg < 0:
        ax.text(i, neg - 2, f'{neg:.2f}%', ha='center', va='top', fontsize=10, color='red')

ax.set_xticks(index)
ax.set_xticklabels(goods, rotation=90, fontsize=10)


ax.set_ylim(top=30, bottom=-35)  # Adjust the values as needed

plt.ylabel('Percentage Change')
plt.title('Percentage Change of Goods (2020-2022)')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

plt.show()
